# %% [markdown]
#
#  **<center>* Assignment 2:  Basic Statistics Level 2 *</center>**
#
# ***DATASCIENCE***
#
# ***name: GUVVALA SOMASEKHAR REDDY***
#
# ***mail: showmove5697@gmail.com***

# %% [markdown]
# ##Assignment -Basic Statisstics level 2 - set 1
#
# **Topics: Descriptive Statistics and Probability**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as smf
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Question-1)**
#
# **Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2**
#
# Name of company	Measure X
#
# Allied Signal	24.23%
#
# Bankers Trust	25.53%
#
# General Mills	25.41%
#
# ITT Industries	24.14%
#
# J.P.Morgan & Co.	29.62%
#
# Lehman Brothers	28.25%
#
# Marriott	25.81%
#
# MCI	24.39%
#
# Merrill Lynch	40.26%
#
# Microsoft	32.95%
#
# Morgan Stanley	91.36%
#
# Sun Microsystems	25.99%
#
# Travelers	39.42%
#
# US Airways	26.71%
#
# Warner-Lambert	35.00%

# %% [markdown]
# **Ans:**

# %%
company_name = ['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']

measure_x = pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
plt.figure(figsize = (10,10))
plt.pie(measure_x, labels = company_name,shadow = False,
     textprops = {'size':'medium','color':'black'})
plt.title('Name of Companies with respect to measure X', fontweight = 'bold',fontsize = 22, color='Blue')
#plt.savefig('Question1piechart.png')
plt.show()

# %%
# boxplot
sns.boxplot(x=measure_x)
plt.show()

# %%
measure_x=pd.Series(measure_x)

# %%
measure_x
# Out:
# 0     24.23
# 1     25.53
# 2     25.41
# 3     24.14
# 4     29.62
# 5     28.25
# 6     25.81
# 7     24.39
# 8     40.26
# 9     32.95
# 10    91.36
# 11    25.99
# 12    39.42
# 13    26.71
# 14    35.00
# dtype: float64

# %%
print('First Quantile Q1  = ',np.quantile(measure_x,0.25))
print('second Quantile Q2 = ',np.quantile(measure_x,0.50))
print('third Quantile Q3  = ',np.quantile(measure_x,0.75))
print('median             = ',np.median(measure_x))
# Out:
# First Quantile Q1  =  25.47
# second Quantile Q2 =  26.71
# third Quantile Q3  =  33.975
# median             =  26.71

# %%
IQR = Q3 - Q1
print('Interquartile range IQR = ',round(IQR,4))
# Out:
# Interquartile range IQR =  8.505

# %%
upper_bound = Q3+(1.5*IQR)
lower_bound = Q1-(1.5*IQR)
print('upper_bound = ',round(upper_bound,4))
print('lower_bound = ',round(lower_bound,4))
# Out:
# upper_bound =  46.7325
# lower_bound =  12.7125

# %%
Outliers = measure_x[(measure_x <= lower_bound) | (measure_x >= upper_bound)]
print('The outlier in the boxplot:',Outliers)
# Out:
# The outlier in the boxplot: 10    91.36
# dtype: float64

# %%
print('mean of measure_x      is  μ    :',round(measure_x.mean(),4))
print('std of measure_x       is  σ    :',round(measure_x.std(),4))
print('varience of measure_x  is  σ^2  :',round(measure_x.var(),4))
# Out:
# mean of measure_x      is  μ    : 33.2713
# std of measure_x       is  σ    : 16.9454
# varience of measure_x  is  σ^2  : 287.1466

# %% [markdown]
# ---

# %% [markdown]
# **Question-2)**
#
# Answer the following three questions based on the box-plot .
# (i)	What is inter-quartile range of this dataset? (please approximate the numbers) In one line, explain what this value implies.
# (ii)	What can we say about the skewness of this dataset?
# (iii)	If it was found that the data point with the value 25 is actually 2.5, how would the new box-plot be affected?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ANS:**
#
# (i)Let Q3= 12 and Q1 = 5
#  Interquartile range(IQR) is : 12-5=7
#  It Implies the measure where bulk of values are for a given dataset.
#
# (ii)This boxplot has Positive skew (or Right Skewed) as Median is towards bottom of data and is less than Mean
#
# (iii) If it was found that the data point with the value 25 is actually 2.5. In that case there will not be outlier, and may reduce positive skewness of the plot.

# %% [markdown]
# ---

# %% [markdown]
# **Question-3)**
#
# **Answer the following three questions based on the histogram .**
#
# (i)	Where would the mode of this dataset lie?
#
# (ii)	Comment on the skewness of the dataset.
#
# (iii)	Suppose that the above histogram and the box-plot in question 2 are plotted for the same dataset. Explain how these graphs complement each other in providing information about any dataset.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ANS:**
#
# i)Mode will lie between 5 and 10.
#
# ii)This dataset is positive skewed(Right tailed/Right skewed).
#
# iii) If the above histogram and the box plot in question 2 are plotted for
#      the same dataset, then,
#      Both graphs are right-skewed and show value 25 as an outlier.

# %% [markdown]
# ---

# %% [markdown]
# **Question-4)**
#
#  AT&T was running commercials in 1990 aimed at luring back customers who
# had switched to one of the other long-distance phone service providers. One such
# commercial shows a businessman trying to reach Phoenix and mistakenly getting
# Fiji, where a half-naked native on a beach responds incomprehensibly in
# Polynesian. When asked about this advertisement, AT&T admitted that the
# portrayed incident did not actually take place but added that this was an enactment
# of something that “could happen.” Suppose that one in 200 long-distance telephone
# calls is misdirected. What is the probability that at least one in five attempted
# telephone calls reaches the wrong number? (Assume independence of attempts.)

# %% [markdown]
# **Ans:**
#
# Given that
#
# The probability of 1 calls out 5 going to wrong number is 0.24751
#
# one in 200 long-distance telephone calls is misdirected
#
# Let
#
# probability of call misdirecting   p = 1/200 ,
#
# Probability of call not Misdirecting q= 1 - 1/200 = 199/200   and
#
# Number of Calls n = 5
#
# Then by binomial distribution, we have
# P(x) = ⁿCₓpˣqⁿ⁻ˣ
#
#
# at least one in five attempted telephone calls reaches the wrong number
#
# = 1  -  none of the call reaches the wrong number(i.e x=0)
#
# = 1  - P(0)
#
#
# = 1   -  ⁵C₀(1/200)⁰(199/200)⁵⁻⁰
#
# = 1 - (1)(1)(199/200)⁵
#
# = 1  -  (199/200)⁵
#
# = 0.02475
#
# ∴ Probability that at least one in five attempted telephone calls reaches the wrong number = **0.02475**

# %% [markdown]
# **Question-5)**
#
# Returns on a certain business venture, to the nearest $1,000, are known to follow the following probability distribution
#
# ![image.png](data:image/png;base64,...)
#
#
# (i)	What is the most likely monetary outcome of the business venture?
#
#
# (ii)	Is the venture likely to be successful? Explain
#
#
# (iii)	What is the long-term average earning of business ventures of this kind? Explain
#
#
# (iv)	What is the good measure of the risk involved in a venture of this kind? Compute this measure

# %% [markdown]
# **ANS:**
#
# Given that
#  The Probability distribution of Returns on a certain business venture, to the nearest $1,000
#
# We know that
#
# E(X) = ∑X . P(X)
#
# E(X²) = ∑X² . P(X)
#
# Var (X) = E(X²)  - ( E(X) )²
#
# SD = sqrt(Var)
#
# ![image.png](data:image/png;base64,...)
#
# (i)  Most likely monetary outcome of the business venture is $ 2000 as it has maximum Probability  0.3
#
# (ii) Venture is successful if X is + ve
#
# Hence if X is 1000 , 2000 or 3000
#
# Probability is  0.2 + 0.3 + 0.1 = 0.6
#
# as 0.6 > 0.5 Hence venture likely to be successful
#
# (iii)   long-term average earning of business ventures  = E(X)
#
# E(X) = ∑ X.P(X)  = $ 800
#
# (iv) Risk involved in a venture
#
# Var (X) = E(X²)  - ( E(X) )²
#
# =   2800000 -   800²
#
# = 2160000  ( High)
#
# SD = √Var  ≈ $ 1470
#
# As Variability is Quite high  hence Risk is high

# %% [markdown]
# ## Assignment - Basic statistics level 2 -set 2
#
# **Topics: Normal distribution, Functions of Random Variables**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from scipy import stats

# %% [markdown]
# **Question-1)**
# **The time required for servicing transmissions is normally distributed with µ = 45 minutes and σ  = 8 minutes. The service manager plans to have work begin on the transmission of a customer’s car 10 minutes after the car is dropped off and the customer is told that the car will be ready within 1 hour from drop-off. What is the probability that the service manager cannot meet his commitment?**
#
#  **A.	0.3875
# B.	0.2676
# C.	0.5
# D.	0.6987**

# %% [markdown]
# Ans:***B.  0.26***
#
# Explanation:
#
# Given That
# The time required for servicing transmissions is normally distributed with
#
# mean µ  = 45 minutes and
#
# standard deviation σ = 8 minutes.
#
# The service manager plans to have work begin on the transmission of a customer’s car 10 minutes after the car is dropped off,
#
# Then
# lets take new mean = 45+10 =55 .
#
# And also the customer is told that the car will be ready within 1 hour from drop-off.
# i.e  x = 60.

# %%
print(" The probability that the service manager cannot meet his commitment is : ",np.round(stats.norm.sf(x=60, loc = 55,scale=8),4))
# Out:
#  The probability that the service manager cannot meet his commitment is :  0.266

# %% [markdown]
# ---

# %% [markdown]
# **Question-2)**
#
#  **The current age (in years) of 400 clerical employees at an insurance claims processing center is normally distributed with mean µ = 38 and Standard deviation σ =6. For each statement below, please specify True/False. If false, briefly explain why.**
#
#   **A.	More employees at the processing center are older than 44 than between 38 and 44.**
#
# **B.	A training program for employees under the age of 30 at the center would be expected to attract about 36 employees.**

# %% [markdown]
# Ans:
#
# Given that,
#
# The current age (in years) of 400 clerical employees at an insurance claims processing center is normally distributed with
#
#  mean µ = 38 and Standard deviation σ =6
#
#  **A.** More employees at the processing center are older than 44 than between 38 and 44.
#
#  Ans: **False**

# %%
# A.
print('The probability of employee age more than 44 is      :' ,round(1- stats.norm.cdf(44,38,6),3)*100,'%')
print('The probability of employee age between 38 and 44 is :' ,round(stats.norm.cdf(44,38,6)-stats.norm.cdf(38,38,8),3)*100,'%')
print(' \n Number of employees  at the processing center are older than 44    : ', round(400 *(1- stats.norm.cdf(44,38,6))))
print(' \n Number of employees  at the processing center whose age is between 38 and 44 : '
, round(400 *(stats.norm.cdf(44,38,6)-stats.norm.cdf(38,38,8))))
print('\n ∴ More employees at the processing center are older than 44 than between 38 and 44 is :',
      (round(400 *(1- stats.norm.cdf(44,38,6))) > round(400 *(stats.norm.cdf(44,38,6)-stats.norm.cdf(38,38,8)))))
# Out:
# The probability of employee age more than 44 is      : 15.9 %
# The probability of employee age between 38 and 44 is : 34.1 %
#
#  Number of employees  at the processing center are older than 44    :  63
#
#  Number of employees  at the processing center whose age is between 38 and 44 :  137
#
#  ∴ More employees at the processing center are older than 44 than between 38 and 44 is : False

# %% [markdown]
# **B.** A training program for employees under the age of 30 at the center would be expected to attract about 36 employees.
#
# Ans:**True**

# %%
#B.
print('The probability a training program for employees under the age of 30 at the center is',round(stats.norm.cdf(30,38,6),3)*100,'%')
print(' \n Number of employees under te age 30 at the center :',round(400*stats.norm.cdf(30,38,6)))
print('\n ∴ A training program for employees under the age of 30 at the center would be expected to attract about 36 employees is :',
   (round(400*stats.norm.cdf(30,38,6))==36))
# Out:
# The probability a training program for employees under the age of 30 at the center is 9.1 %
#
#  Number of employees under te age 30 at the center : 36
#
#  ∴ A training program for employees under the age of 30 at the center would be expected to attract about 36 employees is : True

# %% [markdown]
# ---

# %% [markdown]
# **Question-3)**
#
# **If X1 ~ N(μ, σ2) and X2 ~ N(μ, σ2) are iid normal random variables, then what is the difference between 2 X1 and X1 + X2? Discuss both their distributions and parameters.**

# %% [markdown]
# Ans:  **The difference between the two says that the two given variables are identically and independently distributed**
#
# Explanation:
#
# According to the Central Limit Theorem, any large sum of independent, identically distributed random variables is approximately Normal.
#
# The Normal distribution is defined by two parameters, the mean µ, and the variance σ^2  and written as  X ∼ N(µ, σ^2).
#
# Given X1 ~ N(µ, σ^2) and X2 ~ N(µ ,σ^2)  are two independent identically distributed random variables.
#
# From the properties of normal random variables,
#
# If X ∼ N(µ1, σ1^2) and Y ∼ N(µ2, σ2^2)  are two independent identically distributed random variables then
#
# The sum of normal random variables is given by
# X+Y ∼ N(µ1 + µ2, σ1^2 + σ2^2 )
#         ,
#
# and the difference of normal random variables is given by
#
# X-Y ∼ N(µ1 - µ2, σ1^2 + σ2^2 )
#
#
# When Z=aX , the product of X is given by
#  Z ∼ N(aµ1, (a^2)(σ1^2))
#
#
# When Z= aX+bY , the linear combination of X and Y is given by
#
#  Z ∼ N(aµ1+bµ2, (a^2)(σ1^2)+ (b^2)(σ2^2))
#
#
#
# Now, for 2X1
#
# Here a=2, Then
#
# 2X1~ N(2 µ ,(4) (σ^2))
#
# and for X1+X2
#
# Here a=b=1
#
# X1+X2 ~  N(µ + µ, σ^2 + σ^2 ) ~ N(2 µ, 2 σ^2 )
#
# And the difference between the two is given by
#
# 2X1 - (X1+X2) ~ N(2µ-2µ, 4 σ^2 +2 σ^2)  ~ N(0, 6 σ^2)
#
#
#
# The mean of 2X1 and X1+X2 is same but the var(σ^2) of  2X1 is 2 times more than the variance of X1+X2 .
#
# ∴ The difference between the two says that the two given variables are identically and independently distributed.

# %% [markdown]
# ---

# %% [markdown]
# **Question-4)**
#
# **Let X ~ N(100, 20^2). Find two values, a and b, symmetric about the mean, such that the probability of the random variable taking a value between them is 0.99.**
#
# **A.	90.5, 105.9**
#
# **B.	80.2, 119.8**
#
# **C.	22, 78**
#
# **D.	48.5, 151.5**
#
# **E.	90.1, 109.9**

# %% [markdown]
# Ans:
#
# **D:48.5, 151.5**
#
# Explanation:
#
# Given X ~ N(100, 20^2)
#
# and the mean μ = 100  and standard deviation σ=20.
#
#
# we need to find 'a' and 'b'  in p(a<x<b)=0.99 .

# %%
print(' ∴  The required interval is : ', np.round(stats.norm.interval(0.99,100,20),1))
# Out:
#  ∴  The required interval is :  [ 48.5 151.5]

# %% [markdown]
# ---

# %% [markdown]
# **Question-5)**
#
# **Consider a company that has two different divisions. The annual profits from the two divisions are independent and have distributions Profit1 ~ N(5, 3^2) and Profit2 ~ N(7, 4^2) respectively. Both the profits are in dollor Million.
# Answer  the  following questions about the total profit of the company in Rupees. Assume that $1 = Rs. 45**
#
# **A.Specify a Rupee range (centered on the mean) such that it contains 95% probability for the annual profit of the company.**
#
# **B.	Specify the 5th percentile of profit (in Rupees) for the company**
#
# **C.	Which of the two divisions has a larger probability of making a loss in a given year?**

# %% [markdown]
# Ans:
#
#  Profit1 ~ N(5, 3^2) and Profit2 ~ N(7, 4^2)

# %%
# Combine Mean Profit of both division for Company= mean1 + mean2
mean1 = 5
mean2 = 7
Mean = (mean1+mean2) # 1 USD = 45 rupees
print('The Mean Profit of both division:',Mean, 'Million (in $)',' = ',(Mean*45), 'million(in Rs)')
# Combine standard Deviation = (Std1^2 + Std2^2)^1/2
std1 = 3**2
std2 = 4**2
Std = np.sqrt(std1 + std2)
print('\n The Standard Deviation of both division:', Std, 'Million (in $)','= ', (Std*45), 'million(in Rs)')
# Out:
# The Mean Profit of both division: 12 Million (in $)  =  540 million(in Rs)
#
#  The Standard Deviation of both division: 5.0 Million (in $) =  225.0 million(in Rs)

# %% [markdown]
# **A.**Specify a Rupee range (centered on the mean) such that it contains 95% probability for the annual profit of the company.
#
# Ans:**99.0 million to 981.0 million(in Rs)**

# %%
r1, r2 = np.round(stats.norm.interval(0.95, Mean, Std),2)
print('Rupee Ranges  from',r1,'million to',r2,'Million (in $) in Annual profit of the Company 95% of the time')
print('\n Rupee Ranges from',np.round(np.multiply(r1,45),2),'million to',np.round(np.multiply(r2,45),2),
      'million(in Rs) in Annual profit of the Company 95% of the time')
# Out:
# Rupee Ranges  from 2.2 million to 21.8 Million (in $) in Annual profit of the Company 95% of the time
#
#  Rupee Ranges from 99.0 million to 981.0 million(in Rs) in Annual profit of the Company 95% of the time

# %% [markdown]
# **B.** Specify the 5th percentile of profit (in Rupees) for the company.
#
# Ans:**170.0 Million (in Rs)**
#
#
# we know that
#    Z = (x - μ)/σ
#
#
#  => x =  (Z*σ)+μ

# %%
Z= stats.norm.ppf(0.05)
Fifth_percentile = (Z * Std) + Mean
print('The 5th percentile of Profit for the company is :',np.round(Fifth_percentile,2),'Million (in $)',
      ' = ' ,np.round(Fifth_percentile*45),'Million (in Rs)')
# Out:
# The 5th percentile of Profit for the company is : 3.78 Million (in $)  =  170.0 Million (in Rs)

# %% [markdown]
# **C.** Which of the two divisions has a larger probability of making a loss in a given year?
#
# Ans: **The Division 1 has a larger Probability of making a loss**

# %%
print('\n The Probability of Division #1 making a loss is',np.round((stats.norm.cdf(0,5,3))*100,2),'%')


print('\n The Probability of Division #2 making a loss is',np.round((stats.norm.cdf(0,7,4))*100,2),'%')
Division1 = (stats.norm.cdf(0,5,3))*100
Division2 = (stats.norm.cdf(0,7,4))*100

if Division1>Division2:
    print('\n The Division 1 has a larger Probability of making a loss')
else:
    print('\n The Division 2 has a larger Porbability of making a loss')
# Out:
#  The Probability of Division #1 making a loss is 4.78 %
#
#  The Probability of Division #2 making a loss is 4.01 %
#
#  The Division 1 has a larger Probability of making a loss

# %% [markdown]
# ---

# %% [markdown]
# ##Assignment - Basic Statistics Level - 2 set 3
#
# **Topics: Confidence Intervals**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from scipy import stats

# %% [markdown]
# **Question-1)	For each of the following statements, indicate whether it is True/False. If false, explain why.**
#
# **I.	The sample size of the survey should at least be a fixed percentage of the population size in order to produce representative results.**
#
# ANS: TRUE
#
# **II.	The sampling frame is a list of every item that appears in a survey sample, including those that did not respond to questions.**
#
# ANS: FALSE
#
# Sampling frame is a Frame that could be used as a basis for sampling (allows determining Probability of selection) and normally is any list, material or device that delimits, identifies, and allows access to the elements of the Survey population
#
# **III.	Larger surveys convey a more accurate impression of the population than smaller surveys.**
#
# ANS: TRUE

# %% [markdown]
# ---

# %% [markdown]
# **Question-2)	PC Magazine asked all of its readers to participate in a survey of their satisfaction with different brands of electronics. In the 2004 survey, which was included in an issue of the magazine that year, more than 9000 readers rated the products on a scale from 1 to 10. The magazine reported that the average rating assigned by 225 readers to a Kodak compact digital camera was 7.5. For this product, identify the following:**
#
# **A. The population**
#
# *ans*:  9000
#
# **B. The parameter of interest**
#
# *ans*:  Sample size,average,scale
#
# **C. The sampling frame**
#
# *ans*:   All readers of magazine where survey was inlcuded
#
# **D. The sample size**
#
# *ans*:  225
#
# **E. The sampling design**
#
# *ans*:  Voluntary Survey
#
# **F. Any potential sources of bias or other problems with the survey or sample**
#
# *ans*:  since it is a volunteer survey, people who are rated may be extremely satisfied or extremely dissatisfied. So these responses may not represent actual results.

# %% [markdown]
# **Question-3)	For each of the following statements, indicate whether it is True/False. If false, explain why.**
#
# **I. If the 95% confidence interval for the average purchase of customers at a department store is 💲 50 to 💲 110, then 💲 100 is a plausible value for the population mean at this level of confidence.**
#
# *ans*: TRUE
#
# **II.	If the 95% confidence interval for the number of moviegoers who purchase concessions is 30% to 45%, this means that fewer than half of all moviegoers purchase concessions.**
#
# *ans*: TRUE
#
# **III. The 95% Confidence-Interval for μ only applies if the sample data are nearly normally distributed.**
#
# *ans*: False
#
# The distribution of the sample mean is normal when you have a sufficient number of observations, due to the Central Limit Theorem (see the reading and the course workbook from last time).

# %% [markdown]
# ---

# %% [markdown]
# **Question-4) What are the chances that x̄ >  μ  ?**
#
# **A.	¼**
#
# **B.	½**
#
# **C.	¾**
#
# **D.	1**
#
# *ans:* 1/2
#
# There may or may not be only two possibilities.

# %% [markdown]
# ---

# %% [markdown]
# **Question-5) In January 2005, a company that monitors Internet traffic (WebSideStory) reported that its sampling revealed that the Mozilla Firefox browser launched in 2004 had grabbed a 4.6% share of the market.**
#
# **I. If the sample were based on 2,000 users, could Microsoft conclude that Mozilla has a less than 5% share of the market?**
#
# **II.	WebSideStory claims that its sample includes all the daily Internet users. If that’s the case, then can Microsoft conclude that Mozilla has a less than 5% share of the market?**

# %% [markdown]
# *ANS:*
#
# **I.** If the sample were based on 2,000 users, could Microsoft conclude that Mozilla has a less than 5% share of the market?
#
# **YES**
#
#  Mozila share is less than 5% of the market share
#
# H0: Mozilla's Market share >= 5% of market share
#
# H1: Mozilla's market share is < 5%
#
# Test: One-sample z-test for proportions
#
#
# statistical value z =(p^- p0)/SQRT(p0(1-p0)/n).
#
#
# where:
# z= test statistical value
#
# p0 = Null Hypothesis value ie. 5 or 0.05
#
#
# p^: observerd propotion i.e 4.6% or 0.046
# n=sample size
#
#
# z= (0.046-0.05)/(SQRT(0.05(1-0.05)/2000)
#
# z=(-0.004).(SQRT(-4/2000))
#
# z= -0.82078
#
#
# Critical value assumption:
# Confidence level is 95% and significance level is 5%
#
# The critical value of z as per ztables is -1.96 at 95% confidence level.
#
# statistical value (-0.82078) is greater than crtical value(-1.96) for given sample we rejcet the null hypothesis (H0).
#
# **∴ Mozilla market share for 2000 sample is less than 5% share of the market**
#
# **II.** WebSideStory claims that its sample includes all the daily Internet users. If that’s the case, then can Microsoft conclude that Mozilla has a less than 5% share of the market?
#
# **YES**
#
# Here,we have data on entire population and the sample value reflects the population number.
#
# **∴ Mozilla has a less than 5% share of the market**

# %%
z=(0.046-0.05)/(np.sqrt((0.05*(1-0.05))/2000))
z
# Out:
# -0.820782681668124

# %% [markdown]
# ---

# %% [markdown]
# **Question-6) A book publisher monitors the size of shipments of its textbooks to university bookstores. For a sample of texts used at various schools, the 95% confidence interval for the size of the shipment was 250 ± 45 books. Which, if any, of the following interpretations of this interval are correct?**
#
# **A.	All shipments are between 205 and 295 books.**
#
# ans: INCORRECT
#
# The interval of (205,905) is for 95% confidence level not for 100%
#
# **B.	95% of shipments are between 205 and 295 books.**
#
# ans: INCORRECT
#
# The 95% confidence interval doesn't describe individual shipments.
#
#
# **C.	The procedure that produced this interval generates ranges that hold the population mean for 95% of samples.**
#
# ans: CORRECT
#
# 95% of interval created as the population contained in it.
#
# **D.	If we get another sample, then we can be 95% sure that the mean of this second sample is between 205 and 295.**
#
# ans: INCORRECT
#
# The Interval can not be accurate about the mean of another sample.
#
# **E.	We can be 95% confident that the range 160 to 340 holds the population mean.**
#
# ans: INCORRECT
#
# This interval of 160–340 doesn't correspond to the 95% confidence level.

# %% [markdown]
# ---

# %% [markdown]
# **Question-7)	Which is shorter: a 95% z-interval or a 95% t-interval for μ if we know that σ =s?**
#
# **A.	The z-interval is shorter**
#
# **B.	The t-interval is shorter**
#
# **C.	Both are equal**
#
# **D.	We cannot say**
#
# ans: **A**
#
# z-interval is always shorter because t-critical value cannot be smaller than z-critical value.
#
# ∴ The z-interval is shorter

# %%
# taking n-1 = 10 (any)

print(' 95% z-interval :',stats.norm.interval(0.95))

print(' 95% t-interval :',stats.t.interval(0.95,5))
# Out:
#  95% z-interval : (-1.959963984540054, 1.959963984540054)
#  95% t-interval : (-2.5705818366147395, 2.5705818366147395)

# %% [markdown]
# ---

# %% [markdown]
# **Questions 8 and 9 are based on the following: To prepare a report on the economy, analysts need to estimate the percentage of businesses that plan to hire additional employees in the next 60 days.**

# %% [markdown]
# **Question-8)	How many randomly selected employers (minimum number) must we contact in order to guarantee a margin of error of no more than 4% (at 95% confidence)?**
#
# **A.	600
# B.	400
# C.	550
# D.	1000**

# %% [markdown]
# Ans:  **A**=600
#
# z value at 95% confidence level = 1.96
#
# Given  error = 4% = 0.04
#
# (Margin of Error)^2 = (Z-Score )^2× (P(1-P)) / n
#
# n= (Z-Score )^2× (P(1-P))/(Margin of Error)^2
#
# p = 0.5
#
# 1-p = 0.5

# %%
print('\n number of employees must we contact in order to guarantee a margin of error of no more than 4%  :',
      round(np.power(1.96,2)*(0.5)*(1-0.5)/(np.power(0.04,2))))
# Out:
#  number of employees must we contact in order to guarantee a margin of error of no more than 4%  : 600

# %% [markdown]
# ---

# %% [markdown]
# **Question-9) Suppose we want the above margin of error to be based on a 98% confidence level. What sample size (minimum) must we now use?**
#
#  **A.	1000
# B.	757
# C.	848
# D.	543**

# %% [markdown]
# Ans: **C**=848
#
# z value at 98% confidence level = 2.33
#
# Given error = 4% = 0.04
#
# (Margin of Error)^2 = (Z-Score )^2× (P(1-P)) / n
#
# n= (Z-Score )^2× (P(1-P))/(Margin of Error)^2
#
# p = 0-5
#
# 1-p = 0.5

# %%
print('\n number of employees must we contact in order to guarantee a margin of error of no more than 4%  :',
      round(np.power(2.33,2)*(0.5)*(1-0.5)/(np.power(0.04,2))))
# Out:
#  number of employees must we contact in order to guarantee a margin of error of no more than 4%  : 848

# %% [markdown]
# ---

# %% [markdown]
# ##Assignment - Basic Statistics Level-2 set-4
#
# **Topics: Sampling Distributions and Central Limit Theorem**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from scipy import stats

# %% [markdown]
# **Question-1)**
#
# **Examine the following normal Quantile plots carefully. Which of these plots indicates that the data …**
#
#
# ![image.png](data:image/png;base64,...)
#
# **I.	Are nearly normal?**
#
# ans: Plot **C**
#
# **II.	Have a bimodal distribution? (One way to recognize a bimodal shape is a “gap” in the spacing of adjacent data values.)**
#
# ans: plots **B** and **D**
#
# **III.	Are skewed (i.e. not symmetric) ?**
#
# ans: plots **A, B** and **D**
#
# **IV.	Have outliers on both sides of the center?**
#
# ans: plots **B** and **D**

# %% [markdown]
# ---

# %% [markdown]
# **Question-2)**
#
# **For each of the following statements, indicate whether it is True/False. If false, explain why.**
#
# **The manager of a warehouse monitors the volume of shipments made by the delivery team. The automated tracking system tracks every package as it moves through the facility. A sample of 25 packages is selected and weighed every day. Based on current contracts with customers, the weights should have μ = 22 lbs. and σ = 5 lbs.**
#
# **i)Before using a normal model for the sampling distribution of the average package weights, the manager must confirm that weights of individual packages are normally distributed.**
#
# ans: TRUE
#
#  Based on the central limit theorem, the sampling distribution of the sample mean approach normal distribution as the sample size become bigger (over 30)
#
# **ii)The standard error of the daily average SE(x ̅) = 1.**
#
# ans: TRUE
#
# Standard error = std/sqrt(std) = 5/sqrt(25) =1

# %% [markdown]
# ---

# %% [markdown]
# **Question-3)**
#
# **Auditors at a small community bank randomly sample 100 withdrawal transactions made during the week at an ATM machine located near the bank’s main branch. Over the past 2 years, the average withdrawal amount has been  💲 50 with a standard deviation of 💲 40. Since audit investigations are typically expensive, the auditors decide to not initiate further investigations if the mean transaction amount of the sample is between 💲 45 and 💲 55. What is the probability that in any given week, there will be an investigation?**
#
# **A.	1.25%
# B.	2.5%
# C.	10.55%
# D.	21.1%
# E.	50%**

# %% [markdown]
# Ans:  **D.21.1%**
#
# Let
#
# Given mean μ=50   and
#
# standard deviation σ=40.
#
# sample size n= 100
#
# x1=45 and  x2=55

# %%
z_45 = (45-50)/(40/np.sqrt(100))
print('z value at x1=45 is:',z_45)
z_55 = (55-50)/(40/np.sqrt(100))
print('z value at x2=55 is:',z_55)
print('\n ∴ The probablity of requiring an investigation in any given week will be',
      np.round(1- (stats.norm.cdf(z_55)-stats.norm.cdf(z_45)),4)*100,'%')
# Out:
# z value at x1=45 is: -1.25
# z value at x2=55 is: 1.25
#
#  ∴ The probablity of requiring an investigation in any given week will be 21.13 %

# %% [markdown]
# ---

# %% [markdown]
# **Question-4)**
#
# **The auditors from the above example would like to maintain the probability of investigation to 5%. Which of the following represents the minimum number transactions that they should sample if they do not want to change the thresholds of 45 and 55? Assume that the sample statistics remain unchanged.**
#
# **A.	144
# B.	150
# C.	196
# D.	250
# E.	Not enough information**

# %% [markdown]
# Ans: **D =** 246 **≈ 250**
#
# The probability of investigation to 5%
#
# We have zcore for 95% (100-5) as  1.96.
# i.e z= 1.95
#
# Let
#  mean μ=50   and
#
# standard deviation σ=40,
#
# x1=45,  x2=55,
#
# sample size = n
#
# we know that,
#
# z= (sample mean - population mean)/(standrad deviation/sqrt(sample size))
#
# z = (x-μ)/(σ/sqrt(n))
#
# => n = (z.σ/((x-μ))^2

# %%
print("The required sample size should be with sample mean x= 55 : ",np.round((np.power((1.96*40)/(55-50),2))))
print("The required sample size should be with sample mean x= 45 : ",np.round((np.power((1.96*40)/(45-50),2))))
# Out:
# The required sample size should be with sample mean x= 55 :  246.0
# The required sample size should be with sample mean x= 45 :  246.0

# %% [markdown]
# ---

# %% [markdown]
# **Question-5)**
#
# **An educational startup that helps MBA aspirants write their essays is targeting individuals who have taken GMAT in 2012 and have expressed interest in applying to FT top 20 b-schools. There are 40000 such individuals with an average GMAT score of 720 and a standard deviation of 120. The scores are distributed between 650 and 790 with a very long and thin tail towards the higher end resulting in substantial skewness. Which of the following is likely to be true for randomly chosen samples of aspirants?**
#
# **A.	The standard deviation of the scores within any sample will be 120.**
#
# ans: FALSE
#
# since we don't know the sample size
#
# **B.	The standard deviation of the mean of across several samples will be 120.**
#
# ans: FALSE
#
# Not restricted, It may be more or less.
#
# **C.	The mean score in any sample will be 720.**
#
# ans:  Likely to be **TRUE**
#
#
# **D.	The average of the mean across several samples will be 720.**
#
# ans:  Likely to be **TRUE**
#
# Data is distributed with leptokurtic kurtosis mean more information at the center and lesser information at the tail. This mean there is higher chance that average of mean of a aspirant that randomly chosen will be 720 that fall in between 650 and 790 at the center
#
# **E.	The standard deviation of the mean across several samples will be 0.60**
#
# ans:  Likely to be **TRUE**
#
# Standard Error Mean = 120/sqrt(40000) = 0.6

# %% [markdown]
# ---
#
#                                                                   THANK YOU
#
#
#
# ---
